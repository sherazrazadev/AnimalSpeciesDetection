# %% [markdown]
# # First i mounted Google Drive

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
ROOT_DIR ='/content/gdrive/MyDrive/data'

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.2/566.2 kB 11.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 25.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# # i used YOLOv8 model for this project

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 84.3MB/s]

# %% [markdown]
# i used dataset from kaggle and pick 2 categories and labeled it and used like yolov8 asked to set folders

# %%
model.train(data= "/content/gdrive/MyDrive/data/config.yaml", epochs = 15)
# Out:
# Ultralytics YOLOv8.0.96 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train/weights/best.pt")

# %%
infer.predict(data = "/content/gdrive/MyDrive/data/images/train", save = True , save_txt= True)
# Out:
# WARNING ⚠️ 'source' is missing. Using 'source=https://ultralytics.com/images/bus.jpg'.
#
# ...
# 100%|██████████| 476k/476k [00:00<00:00, 12.6MB/s]
# image 1/1 /content/bus.jpg: 640x480 1 Sheep, 2 Squirrels, 12.6ms
# Speed: 3.4ms preprocess, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Sheep', 1: 'Squirrel'}
#  orig_img: array([[[122, 148, 172],
#          [120, 146, 170],
#          [125, 153, 177],
#          ...,
#          [157, 170, 184],
#          [158, 171, 185],
#          [158, 171, 185]],
#
#         [[127, 153, 177],
#          [124, 150, 174],
#          [127, 155, 179],
#          ...,
#          [158, 171, 185],
#          [159, 172, 186],
#          [159, 172, 186]],
#
# ...

# %% [markdown]
# i have 1 error of machine so i solved with follow code you ignore this 1 cell code

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %% [markdown]
# give the path of trained model and input image

# %%
# !yolo detect predict model="/content/runs/detect/train/weights/best.pt" source="/content/gdrive/MyDrive/data/1.jpeg"
# Out:
# Ultralytics YOLOv8.0.96 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/gdrive/MyDrive/data/1.jpeg: 640x480 1 Squirrel, 56.2ms
# Speed: 3.7ms preprocess, 56.2ms inference, 92.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict2

# %%
# !yolo detect predict model="/content/runs/detect/train/weights/best.pt" source="/content/gdrive/MyDrive/data/1.mp4"
# Out:
# Ultralytics YOLOv8.0.96 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 87.8ms
# video 1/1 (2/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 8.5ms
# video 1/1 (3/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Sheep, 1 Squirrel, 7.7ms
# video 1/1 (4/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 8.3ms
# video 1/1 (5/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 10.4ms
# video 1/1 (6/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 7.9ms
# video 1/1 (7/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 11.1ms
# video 1/1 (8/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 7.8ms
# video 1/1 (9/822) /content/gdrive/MyDrive/data/1.mp4: 384x640 1 Squirrel, 10.1ms
# ...

# %%
# !yolo detect predict model="/content/runs/detect/train/weights/best.pt" source="/content/gdrive/MyDrive/data/2.mp4"
# Out:
# Ultralytics YOLOv8.0.96 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 12 Sheeps, 52.4ms
# video 1/1 (2/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 12 Sheeps, 7.1ms
# video 1/1 (3/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 13 Sheeps, 7.9ms
# video 1/1 (4/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 13 Sheeps, 6.6ms
# video 1/1 (5/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 13 Sheeps, 7.1ms
# video 1/1 (6/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 14 Sheeps, 7.4ms
# video 1/1 (7/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 14 Sheeps, 7.0ms
# video 1/1 (8/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 13 Sheeps, 6.8ms
# video 1/1 (9/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 12 Sheeps, 7.1ms
# video 1/1 (10/781) /content/gdrive/MyDrive/data/2.mp4: 384x640 12 Sheeps, 6.9ms
# ...
